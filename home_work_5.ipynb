# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Задание 1
# Известно, что генеральная совокупность распределена нормально
# со средним квадратическим отклонением, равным 16.
# Найти доверительный интервал для оценки математического ожидания a с надежностью 0.95,
# если выборочная средняя M = 80, а объем выборки n = 256.

# %% [markdown]
# $$T_{1,2} = \overline{X} \pm \delta$$

# %% [markdown]
# $$\delta = \frac{t_{\lambda} \cdot \sigma}{\sqrt{n}}$$

# %% [markdown]
# $\sigma = 16$
# $\lambda = 0.95$
# $\overline{X} = 80$
# $n = 256$

# %% [markdown]
# Коэффициент доверия по таблице значений функции Лапласа для Ф = 0,95/2

# %%
0.95/2
# Out:
# 0.475

# %% [markdown]
# $t_{\lambda} = 1.96$

# %%
delta = 1.96 * 16 / (256 ** 0.5)
delta
# Out:
# 1.96

# %%
T1 = 80 - delta
T1
# Out:
# 78.04

# %%
T2 = 80 + delta
T2
# Out:
# 81.96

# %%
print(f'Ответ: ({T1}, {T2})')
# Out:
# Ответ: (78.04, 81.96)

# %% [markdown]
# # Задание 2
# В результате 10 независимых измерений некоторой величины X, выполненных с одинаковой точностью,
# получены опытные данные:
# 6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1
# Предполагая, что результаты измерений подчинены нормальному закону распределения вероятностей,
# оценить истинное значение величины X при помощи доверительного интервала, покрывающего это
# значение с доверительной вероятностью 0,95.

# %%
X = pd.DataFrame([6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1])

# %%
X.mean()
# Out:
# 0    6.59
# dtype: float64

# %%
X.std()
# Out:
# 0    0.450802
# dtype: float64

# %%
X.shape[0]
# Out:
# 10

# %% [markdown]
# $\sigma = 0.45$
# $\lambda = 0.95$
# $\overline{X} = 6.59$
# $n = 10$

# %% [markdown]
# $t_{\lambda} = 1.96$

# %% [markdown]
# $$\delta = \frac{t_{\lambda} \cdot \sigma}{\sqrt{n}}$$

# %%
delta = 1.96 * 0.45 / (10 ** 0.5)
delta
# Out:
# 0.27891288962685107

# %% [markdown]
# $$T_{1,2} = \overline{X} \pm \delta$$

# %%
T1 = 6.59 - delta
T1
# Out:
# 6.3110871103731485

# %%
T2 = 6.59 + delta
T2
# Out:
# 6.868912889626851

# %%
print(f'Ответ: ({T1}, {T2})')
# Out:
# Ответ: (6.3110871103731485, 6.868912889626851)

# %% [markdown]
# # Задание 3
# Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм.
# Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из n=100 шариков средний диаметр
# оказался равным 17.5 мм, а дисперсия известна и равна 4 мм.

# %% [markdown]
# H0: M = 17

# %% [markdown]
# H1: M > 17

# %%
alpha = 0.05
n = 100
D = 4
X0 = 17
X = 17.5

# %%
U_nabl = (X - X0) / (D ** 0.5) * (n ** 0.5)
U_nabl
# Out:
# 2.5

# %%
Ф = (1 - alpha * 2) / 2
Ф
# Out:
# 0.45

# %% [markdown]
# Критическая точка для односторонней критической области:

# %%
u_kr = 1.645

# %%
U_nabl > u_kr
# Out:
# True

# %% [markdown]
# Наблюдаемое значение критерия попадает в критическую область, значит, нулевая гипотеза должна быть отклонена.

# %% [markdown]
# Ответ: средний диаметр шариков больше 17 мм.

# %% [markdown]
# # Задание 4
# Продавец утверждает, что средний вес пачки печенья составляет 200 г.
# Из партии извлечена выборка из 10 пачек. Вес каждой пачки составляет:
# 202, 203, 199, 197, 195, 201, 200, 204, 194, 190.
# Известно, что их веса распределены нормально.
# Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%?

# %%
X = pd.DataFrame([202, 203, 199, 197, 195, 201, 200, 204, 194, 190])

# %%
X.mean()
# Out:
# 0    198.5
# dtype: float64

# %%
X.std()
# Out:
# 0    4.453463
# dtype: float64

# %%
X.shape[0]
# Out:
# 10

# %% [markdown]
# $\sigma = 4.45$
# $\lambda = 0.99$
# $\overline{X} = 198.5$
# $n = 10$

# %% [markdown]
# $$\delta = \frac{t_{\lambda} \cdot \sigma}{\sqrt{n}}$$

# %% [markdown]
# Коэффициент доверия по таблице значений функции Лапласа для Ф = 0,99/2

# %%
0.99/2
# Out:
# 0.495

# %% [markdown]
# $t_{\lambda} = 2.58$

# %%
delta = 2.58 * 4.45 / (10 ** 0.5)
delta
# Out:
# 3.6306109816393164

# %% [markdown]
# $$T_{1,2} = \overline{X} \pm \delta$$

# %%
T1 = 198.5 - delta
T1
# Out:
# 194.8693890183607

# %%
T2 = 198.5 + delta
T2
# Out:
# 202.1306109816393

# %%
print(f'Ответ: Вес пачки печенья по утверждению продавца попадает в доверительный интервал ({T1}, {T2})')
# Out:
# Ответ: Вес пачки печенья по утверждению продавца попадает в доверительный интервал (194.8693890183607, 202.1306109816393)
